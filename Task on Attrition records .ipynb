# %%
import pandas as pd
import sqlite3 as sql

# %%
database ='''attr_data.db'''
connection = sql.connect(database)

# %%
query = '''SELECT * FROM attrition_records'''

# %%
df = pd.read_sql_query(query, connection)
df.head()
# Out:
#    id  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   1   41       Yes      Travel_Rarely       1102                   Sales
# 1   2   49        No  Travel_Frequently        279  Research & Development
# 2   3   37       Yes      Travel_Rarely       1373  Research & Development
# 3   4   33        No  Travel_Frequently       1392  Research & Development
# 4   5   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    RelationshipSatisfaction  StandardHours StockOptionLevel  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
corr = df.corr()

# %%
corr
# Out:
#                                 id       Age  DailyRate  DistanceFromHome  \
# id                        1.000000 -0.010349  -0.051484          0.032928
# Age                      -0.010349  1.000000   0.010661         -0.001686
# DailyRate                -0.051484  0.010661   1.000000         -0.004985
# DistanceFromHome          0.032928 -0.001686  -0.004985          1.000000
# Education                 0.041901  0.208034  -0.016806          0.021042
# EmployeeCount                  NaN       NaN        NaN               NaN
# EmployeeNumber            0.999906 -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction   0.017424  0.010146   0.018355         -0.016075
# HourlyRate                0.034754  0.024287   0.023381          0.031131
# JobInvolvement           -0.007105  0.029820   0.046135          0.008783
# JobLevel                 -0.018041  0.509604   0.002966          0.005303
# JobSatisfaction          -0.045941 -0.004892   0.030571         -0.003669
# ...

# %%
df.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    735.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       1.000000    18.000000   102.000000          1.000000     1.000000
# 25%     368.250000    30.000000   465.000000          2.000000     2.000000
# 50%     735.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1102.750000    43.000000  1157.000000         14.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
#What do you think are the 3 factors behind employee attrition?

# %%
fig,ax = plt.subplots(1,3, figsize=(20,20))               
plt.suptitle("Distribution of various factors", fontsize=20)
sns.barplot(df['Gender'],df['DistanceFromHome'],hue = df['Attrition'], ax = ax[0]); 
sns.barplot(df['Gender'],df['WorkLifeBalance'],hue = df['Attrition'], ax = ax[1]); 
sns.barplot(df['Gender'],df['NumCompaniesWorked'],hue = df['Attrition'], ax = ax[2]);
# Out:
# /Users/khadijakyauta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/khadijakyauta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.countplot(x='Department',data=df,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
#It can be observed that the further away an employee is from from the more likey they are to leace the company. Work life balance and number of compnies worked also has a negative impact on attrition can also be seen as main reasons for attrition.

# %%
#The Attrition Rate is more in the Research and Development Department. whereas the Attrition Rate is very Less in the HR department

# %%
#What is the relationship between Education and Monthly Income?

# %%
sns.jointplot(x='Education',y='MonthlyIncome',data=df)

# %%
#From the plot we can see that the more educated an employee is the highter their income.

# %%
#What is the effect of age on attrition?

# %%
fig, ax = plt.subplots(figsize=(15,20))
sns.countplot(x='Age',data=df,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
#Here we can see that the Attrition rate is more for people between the age of 29 to 31.

# %%
#Is Income the main factor towards employee attrition?

# %%
sns.set(style = 'whitegrid')    
       
sns.stripplot(x="Attrition", y="MonthlyIncome", data=df)
  
plt.show()

# %%
#In this plot we can see that Monthly Income is not a mian factor of attrition as the rate of attrition comparatively low.

# %%
#How does work-life balance impact the overall attrition rate?

# %%
fig, ax = plt.subplots(figsize=(15,20))
sns.countplot(x='WorkLifeBalance',data=df,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(15,20))
sns.barplot(df['Gender'],df['WorkLifeBalance'],hue = df['Attrition'])
# Out:
# /Users/khadijakyauta/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='WorkLifeBalance'>

# %%
#As can be seen in the plot, there is a positive relationship between work life balance and attrition rate. This can be seen especially in the females.
